# %% [markdown]
# # Car Sensor Data

# %%
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %matplotlib inline

df = pd.read_csv('20170223_Kevin2Work.csv',header=1)

df = df.rename(index=str, columns={'Time': 'Time', 
                              ' Latitude (deg)' : 'Latitude', 
                              ' Longitude (deg)' : 'Longitude', 
                              ' Vehicle speed (MPH)' : 'VehicleSpeed',
                              ' Accel X (g)' : 'AccX',
                              ' Accel Y (g)' : 'AccY',
                              ' Accel Z (g)' : 'AccZ',
                              ' Engine RPM (RPM)' : 'EngineRPM',
                              ' Actual engine - percent torque (%)' : 'ActualEnginePercentTorque',
                              ' Instant fuel economy (MPG)' : 'InstantFuel',
                              ' Total fuel economy (MPG)' : 'TotalFuel',
                              ' Fuel rate (gal/hr)' : 'FuelRate',
                              ' Rotation Rate X (deg/s)' : 'RotX',
                              ' Rotation Rate Y (deg/s)' : 'RotY',
                              ' Rotation Rate Z (deg/s)' : 'RotZ',
                              ' Roll (deg)' : 'Roll',
                              ' Pitch (deg)' : 'Pitch',
                              ' Engine coolant temperature (C)' : 'EngineCoolTemp',
                              ' Intake manifold absolute pressure (psi)' : 'IntakePressure',
                              ' Intake air temperature (C)' : 'IntakeAirTemp',
                              ' Mass air flow rate (lb/min)' : 'MassAirFlowRate',
                              ' Time since engine start (sec)' :'TimeEngineStart',
                              ' Engine oil temperature (C)': 'EngineOilTemp',
                              ' Engine fuel rate (gal/hr)':'EngineFuelRate',
                              " Driver's demand engine - percent torque (%)" : 'DemandEnginePercentTorque',
                              ' Engine reference torque (lb•ft)' : 'EngineReferenceTorque', 
                              ' Boost (psi)' :"Boost", 
                              ' Acceleration (g)' : "Acc",
                              ' Acceleration (Avg) (g)' : "AccAvg", 
                              ' Engine Power (hp)' : "EnginePower",
                              ' Engine Torque (lb•ft)' : "EngineTorque", 
                              ' A/F Commanded' : "AFCommanded", 
                              ' A/F Actual' : 'AFActual',
                              ' Fuel Remaining (gal)' : 'FuelRemaning', 
                              ' GPS Speed (MPH)' : 'GPSSpeed', 
                              ' Accel (Grav) X (g)' : 'AccGravX',
                              ' Accel (Grav) Y (g)' : 'AccGravY', 
                              ' Accel (Grav) Z (g)' : 'AccGravZ',
                              ' Distance traveled while MIL is activated (miles)' : 'MILDistance',
                              ' Total engine run time (sec)' : 'EngineRunTime', 
                              ' Total idle run time (sec)' : 'IdleRunTime',
                              ' Altitude (ft)' : 'Altitude' })

for i in range(len(df)):
    df.ix[i,"Time"] = datetime.datetime.strptime(df.ix[i,"Time"],"%m/%d/%Y %H:%M:%S.%f %p")
    
Acc = df.Acc
AccAvg = df.AccAvg
AccGravX = df.AccGravX
AccGravY = df.AccGravY
AccGravZ = df.AccGravZ
AccX = df.AccX
AccY = df.AccY
AccZ = df.AccZ
ActualEnginePercentTorque = df.ActualEnginePercentTorque
AFActual = df.AFActual
AFCommanded = df.AFCommanded
Altitude = df.Altitude
Boost = df.Boost
DemandEnginePercentTorque = df.DemandEnginePercentTorque
EngineCoolTemp = df.EngineCoolTemp
EngineFuelRate = df.EngineFuelRate
EngineOilTemp = df.EngineOilTemp
EnginePower = df.EnginePower
EngineReferenceTorque = df.EngineReferenceTorque
EngineRPM = df.EngineRPM
EngineRunTime = df.EngineRunTime
EngineTorque = df.EngineTorque
FuelRate = df.FuelRate
FuelRemaning = df.FuelRemaning
GPSSpeed = df.GPSSpeed
IdleRunTime = df.IdleRunTime
InstantFuel = df.InstantFuel
IntakeAirTemp = df.IntakeAirTemp
IntakePressure = df.IntakePressure
Latitude = df.Latitude
Longitude = df.Longitude
MassAirFlowRate = df.MassAirFlowRate
MILDistance = df.MILDistance
Pitch = df.Pitch
Roll = df.Roll
RotX = df.RotX
RotY = df.RotY
RotZ = df.RotZ
TimeEngineStart = df.TimeEngineStart
TotalFuel = df.TotalFuel
VehicleSpeed = df.VehicleSpeed
Time = df.Time

# %%
df.columns
# Out:
# Index(['Time', 'Latitude', 'Longitude', 'VehicleSpeed', 'AccX', 'AccY', 'AccZ',
#        'EngineRPM', 'ActualEnginePercentTorque', 'InstantFuel', 'TotalFuel',
#        'FuelRate', 'RotX', 'RotY', 'RotZ', 'Roll', 'Pitch', 'EngineCoolTemp',
#        'IntakePressure', 'IntakeAirTemp', 'MassAirFlowRate', 'TimeEngineStart',
#        'EngineOilTemp', 'EngineFuelRate', 'DemandEnginePercentTorque',
#        'EngineReferenceTorque', 'Boost', 'Acc', 'AccAvg', 'EnginePower',
#        'EngineTorque', 'AFCommanded', 'AFActual', 'FuelRemaning', 'GPSSpeed',
#        'AccGravX', 'AccGravY', 'AccGravZ', 'MILDistance', 'EngineRunTime',
#        'IdleRunTime', 'Altitude'],
#       dtype='object')

# %%
u = list(set(all_locs))
# Out:
# (459, 42)

# %%
all_locs[0]
# Out:
# '502, Greenwood Avenue Northeast, Linwood, Virginia Highland, Atlanta, Fulton County, Georgia, 30308, United States of America'

# %% [markdown]
# ### To store the locations in a file

# %%
import csv

# Open File
resultFyle = open("locations.csv",'w')
# Write Data to File
for r in u:
    resultFyle.write(r + "\n")
resultFyle.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-eaeaf9aa9b35> in <module>()
#       4 resultFyle = open("locations.csv",'w')
#       5 # Write Data to File
# ----> 6 for r in u:
#       7     resultFyle.write(r + "\n")
#       8 resultFyle.close()
#
# NameError: name 'u' is not defined

# %%
import numpy as np

highways = ['I-75','I-20','I-24','I-59','I-75','I-85','I-95']
street_type = []
for loc in all_locs :  
    for highway in highways:
        if highway in loc :
            street_type.append(1)
            break
        street_type.append(0)

street_type = np.array(street_type)

# %% [markdown]
# ### Checking if there were highways

# %%
np.where(street_type>0)
# Out:
# (array([], dtype=int64),)

# %% [markdown]
# There were no highways in 22nd febraury

# %% [markdown]
# ### Checking if there is a correlation between AccGravX and AccX

# %%
plt.figure(3, figsize=(20, 5))

plt.subplot(1, 3, 1)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.plot(Time,AccX,'b')
plt.plot(Time,AccGravX,'g')
plt.gcf().autofmt_xdate()
plt.title('Acceleration X Time Series')
plt.xlabel('Time (Sec)')
plt.ylabel('Acceleration X')
plt.legend()

plt.subplot(1, 3, 2)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.plot(Time,AccY,'b')
plt.plot(Time,AccGravY,'g')
plt.gcf().autofmt_xdate()
plt.title('Acceleration Y Time Series')
plt.xlabel('Time (Sec)')
plt.ylabel('Acceleration Y')
plt.legend()

plt.subplot(1, 3, 3)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.plot(Time,AccZ,'b')
plt.plot(Time,AccGravZ,'g')
plt.gcf().autofmt_xdate()
plt.title('Acceleration Z Time Series')
plt.xlabel('Time (Sec)')
plt.ylabel('Acceleration Z')
plt.legend()

# %%
print (np.corrcoef(AccX,AccGravX))
# Out:
# [[ 1.         -0.57720652]
#  [-0.57720652  1.        ]]

# %%
print (np.corrcoef(AccY,AccGravY))
# Out:
# [[ 1.         -0.76667474]
#  [-0.76667474  1.        ]]

# %%
print (np.corrcoef(AccZ,AccGravZ))
# Out:
# [[ 1.        -0.5188003]
#  [-0.5188003  1.       ]]

# %% [markdown]
# The acceleration measured by the chip in the phone show in blue is negatively correlated with the acceleration measured by the gps of the car which is shown in green. This might be due to the effect of inertia. In order to meausure the driving trend we will use the acceleration measured by the gps.

# %% [markdown]
# ### GPS Speed and it's moving average

# %%
plt.figure(3, figsize=(20, 5))

plt.subplot(1, 3, 1)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.plot(Time,GPSSpeed,'b')
plt.gcf().autofmt_xdate()
plt.title('GPS Speed')
plt.xlabel('Time (Sec)')
plt.ylabel('Acceleration X')
plt.legend()

plt.subplot(1, 3, 2)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
b = smooth(GPSSpeed, window='flat',window_len=50)
plt.plot(Time,b[:-49])
plt.title('GPS Speed MA 50 with time')
plt.ylabel('GPS Speed MA 50')
plt.xlabel('Time (Sec)')
plt.gcf().autofmt_xdate()
#print (Time.shape,b[:-4].shape)

plt.subplot(1, 3, 3)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
b = smooth(GPSSpeed, window='flat',window_len=300)
plt.plot(Time,b[:-299])
plt.title('GPS Speed MA 300 with time')
plt.ylabel('GPS Speed MA 300')
plt.xlabel('Time (Sec)')
plt.gcf().autofmt_xdate()
#print (Time.shape,b[:-4].shape)

# %% [markdown]
# ## Acceleration (grav) (X,Y,Z)

# %%
plt.figure(3, figsize=(20, 5))

#acc_all = pow(AccGravX,2) + pow(AccGravY,2) + pow(AccGravZ,2)
#acc_all = pow(acc_all,0.5)

acc_all = Acc

plt.subplot(1, 3, 1)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.plot(Time,acc_all,'b')
plt.gcf().autofmt_xdate()
plt.title('Acceleration X Time Series')
plt.xlabel('Time (Sec)')
plt.ylabel('Acceleration X')
plt.legend()

plt.subplot(1, 3, 2)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
b = smooth(acc_all, window='flat',window_len=50)
plt.plot(Time,b[:-49])
plt.title('Acceleration MA 50 with time')
plt.ylabel('Acceleration MA 50')
plt.xlabel('Time (Sec)')
plt.gcf().autofmt_xdate()

plt.subplot(1, 3, 3)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
b = smooth(acc_all, window='flat',window_len=300)
plt.plot(Time,b[:-299])
plt.title('Acceleration MA 300 with time')
plt.ylabel('Acceleration MA 300')
plt.xlabel('Time (Sec)')
plt.gcf().autofmt_xdate()

# %% [markdown]
# ## Roll with respect to speed

# %%
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.plot(Time,GPSSpeed,'b')
plt.plot(Time,Roll,'g')
plt.gcf().autofmt_xdate()
plt.title('Acceleration X Time Series')
plt.xlabel('Time (Sec)')
plt.ylabel('Roll and GPSSpeed')
plt.legend()

# %%
print (np.corrcoef(GPSSpeed,Roll))
# Out:
# [[ 1.         -0.01826669]
#  [-0.01826669  1.        ]]

# %% [markdown]
# So we see that during a turn when speed is low the roll is only slightly higher, inferring a not cautious behavior

# %%
import numpy

def smooth(x,window_len=11,window='hanning'):
    """smooth the data using a window with requested size.
    
    This method is based on the convolution of a scaled window with the signal.
    The signal is prepared by introducing reflected copies of the signal 
    (with the window size) in both ends so that transient parts are minimized
    in the begining and end part of the output signal.
    
    input:
        x: the input signal 
        window_len: the dimension of the smoothing window; should be an odd integer
        window: the type of window from 'flat', 'hanning', 'hamming', 'bartlett', 'blackman'
            flat window will produce a moving average smoothing.

    output:
        the smoothed signal
        
    example:

    t=linspace(-2,2,0.1)
    x=sin(t)+randn(len(t))*0.1
    y=smooth(x)
    
    see also: 
    
    numpy.hanning, numpy.hamming, numpy.bartlett, numpy.blackman, numpy.convolve
    scipy.signal.lfilter
 
    TODO: the window parameter could be the window itself if an array instead of a string
    NOTE: length(output) != length(input), to correct this: return y[(window_len/2-1):-(window_len/2)] instead of just y.
    """ 
     
    if x.ndim != 1:
        raise (ValueError, "smooth only accepts 1 dimension arrays.")

    if x.size < window_len:
        raise (ValueError, "Input vector needs to be bigger than window size.")
        

    if window_len<3:
        return x
    
    
    if not window in ['flat', 'hanning', 'hamming', 'bartlett', 'blackman']:
        raise (ValueError, "Window is on of 'flat', 'hanning', 'hamming', 'bartlett', 'blackman'")
    

    s=numpy.r_[x[window_len-1:0:-1],x,x[-1:-window_len:-1]]
    #print(len(s))
    if window == 'flat': #moving average
        w=numpy.ones(window_len,'d')
    else:
        w=eval('numpy.'+window+'(window_len)')
    
    y=numpy.convolve(w/w.sum(),s,mode='valid')
    return y
